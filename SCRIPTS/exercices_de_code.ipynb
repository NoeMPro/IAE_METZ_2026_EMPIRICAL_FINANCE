# %% [markdown]
# # Premiers exercices

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Analyse bourse")
# Out:
# Analyse bourse

# %% [markdown]
# # Let's go learning Python

# %%
# Ceci est un commentaire dans la cellule de code
# Python est une programmation orienté objet, donc on définit des variables
name = "Noé"
print(name)
name
# Out:
# Noé
# 'Noé'
